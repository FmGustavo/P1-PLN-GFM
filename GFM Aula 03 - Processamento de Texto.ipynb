# %% [markdown]
# # O que é processamento de linguagem natural

# %%
# A - Definição
#   a - Estudando a área da computação que desenvolve técnicas para que os
#       computadores compreendam e interpretem a nossa linguagem,
#       gerando respostas que sejam legíveis.
#
#   b - Destacamos o termo "natural" para nossa linguagem humana,
#       seja ela falada ou escrita.
#
#   c - O PLN possuí duas camadas:
#    1. Compreensão a linguagem natural (NLU) - Conseguir interpretar:
#       i. Identificar as palavras, analise gramatical e sintática e
#          também identificar a lógica na sentença.
#      ii. Exemplo: Qual será o tempo amanhã?
#
#    2. Geração da linguagem natural (NLG) - Gerar a comunicação a
#       partir de uma base de dados própria para responder de acordo
#       com uma entrada previamente realizada.
#
# B - Paradigmas de PLN - abordagens de como os problemas de PLN são resolvidos
#   a - Simbólico - Seguir as regras escritas
#     1. Ex: O carro era bonito. != Carro foi bonito.
#     2. Desvantagem: Qualquer alteração no texto, envolve uma nova base
#        de dados, geralmente vem com novas regras.
#
#   b - Estatistico - Cálculos probabilísticos em coleções de textos.
#       basicamente ele calcula a probabilidade de duas palavras
#       estarem próximas. Palavras próximas.
#     1. Ex: O carro era bonito. == Carro foi bonito. != O carro é belo
#
#   c - Neural - Baseado em aprendizagem neural, utilizados por grandes
#       volumes de dados.
#
#   d - Misto (Híbrido) - uma mistura de todos
#
#
#

# %% [markdown]
# # Qual é o primeiro passo a ser executado (Prática)

# %%
# A - Vamos começar com a parte de interpretação da linguagem
#
# a - Pergunta da noite: Você conseguiria comer feijão cru neste
#     exato momento?
#   1. Essa mesma analogia pode ser usada para o computador receber
#      um texto - pode receber mas não vai fazer bem (nenhuma compreensão)
#
# b - O computador precisa receber o texto tratado  (pré-processamento) é
#     uma preparação para que o conteúdo possa entrar no algoritmo de ML
#     para ser processado e respondido.
#
# c - Os textos brutos são divididos em pedaços que possuam peso (sentido
#     morfológico e sintático) para serem aproveitados.
#
# d - Esse é o processo de limpeza e transformação do texto para ser
#     processado:
#   1. Pontuação e símbolo serão excluídos.
#   2. Palavras comuns são eliminadas.
#   3. Haverá a padronização de letras maiúsculas e minúsculas.
#   4. Haverá a transformação de palavra para sua raiz.
#
# d - Etapas de pré-processamento:
#   1. Normalização de texto - Etapa de ajuste nas letras do texto:
#     a. Transformar tudo em mesma caixa (Minúsculo ou maiúsculo):
#     Boa noite = boa noite = BOA NOITE
#     b. Remoção de acentos: remocao de acentos
#
#   2. Remoção de ruídos - Elementos textuais que não possuem valores
#      textais:
#     a. Confira a atividade de HOJE!!! Link:
#        www.googlecolab.com/rodolfo_aula03
#
#   3. Tokenização - Separaçã do conjunto textual em unidade atômica -
#      palavras:
#     a. O menino foi de onibus para a escola
#     b. O/Menino/Foi/De/Onibus/Para/A/Escola
#
#   4. Remoção de Stopword (palavras comuns) - palavras que não contribuem
#      para o significado da frase
#     a. O/Menino/Foi/De/Onibus/Para/A/Escola
#     b. Menino/Foi/Onibus/Escola
#
#   5. Radicalização - Transformar as palavras para sua versão raiz:
#     a. Radicalização (Stemming) - Corta tudo e deixa apenas a raiz.
#       i. Correu, corrido, correr, corremos = corr
#     b. Lematização (Lemmatizer) - Se torna o infinitivo da palavra.
#       i. Correu, corrido, correr, corremos = correr
