# %% [markdown]
# # Projeto 01 - Análise Quantitativa de Corpus

# %%
# criar uma função para fazer a abertura e leitura do arquivo
def ler(nome_arquivo):
  arquivo = open(nome_arquivo,'r', encoding='utf-8')
  conteudo_arq = arquivo.read()
  arquivo.close()
  return conteudo_arq

# %%
texto = ler ('/content/sample_data/Fitas.txt')
print(len(texto))
# Out:
# 3748

# %% [markdown]
# ## Primeira etapa - Buscador de palavras

# %%
def buscador(alvo, texto):
  texto = texto.replace('\n', '')
  texto = texto.replace('\t', '')

  ocorrencias = []

  encontrado_aqui = texto.find(alvo, 0)
  # Se encontra a palavra, informa a posição
  # Se não encontrar, informa -1

  while encontrado_aqui > 0:
    pos_inicial = encontrado_aqui - (40 - len(alvo))
    trecho = texto[pos_inicial: pos_inicial + 80]

    ocorrencias.append(trecho)

    encontrado_aqui = texto.find(alvo, encontrado_aqui + 1)

    # Inicia a busca a partir da posição anterior + 1
    # Se encontra a palavra, informa a posição
    # Se não encontrar, informa -1

  return ocorrencias

# %%
resultados = buscador(' medo', texto)

for trecho in resultados:
  print (trecho)
# Out:
# proprías leis e um culto bizarro ao medo, sendo originada de alguma revelação pa
# sessão da familia com o conceito do medo, o membro da família Strach que fosse o
#  realizarem suas vontades graças ao medo, a Sofia acredita que os traumas de uma

# %% [markdown]
# ## Segunda Etapa - Limpeza do Corpus

# %%
palavras = texto.split()

# %%
def limpar(lista):
  lixo = '.,:;?!"´`^~()[]{}/\|@#$%¨&*-'
  quase_limpo = [x.strip(lixo).lower() for x in lista]
  return [x for x in quase_limpo if x.isalpha() or '-' not in x]

# %%
teste = "Corre-se atrás do carro, corre se o carro for embora."
word = teste.split()
print (word)
# Out:
# ['Corre-se', 'atrás', 'do', 'carro,', 'corre', 'se', 'o', 'carro', 'for', 'embora.']

# %%
print(limpar(word))
# Out:
# ['atrás', 'do', 'carro', 'corre', 'se', 'o', 'carro', 'for', 'embora']

# %%
print(len(palavras))
palavras = limpar(palavras)
print(len(palavras))
# Out:
# 657
# 657

# %% [markdown]
# Split() - transforma um texto em uma lista de palavras
#
# Strip() - Elimina sinais ou caracteres no começo ou fim de uma palavra
#
# Isalpha - Realiza um filtro eliminando números ou símbolos de uma lista de referência

# %% [markdown]
# ## Terceira Etapa - Quantidade de palavras

# %%
# Conhecer a quantidade de palavras e vocabulário
vocabulario = set(palavras)
len(vocabulario)
# Out:
# 309

# %%
# Calculando a riqueza textual do corpus
riqueza = len(vocabulario) / len(palavras)
riqueza
# Out:
# 0.4703196347031963

# %%
# Criar um dicionário deste texto
from collections import defaultdict
def ocorrencias(lista_palavras):
  dicionario = defaultdict(int)
  for p in lista_palavras:
    dicionario[p] += 1

  return dicionario

# %%
dic = ocorrencias(palavras)
mf = sorted(dic.items(), key=lambda tupla:tupla[1], reverse=True)[:50]
for palavra, n in mf:
  print (palavra,'\t',n)
# Out:
# que 	 35
# o 	 31
# de 	 19
# a 	 16
# do 	 15
# e 	 11
# da 	 10
# medo 	 10
# é 	 10
# eu 	 10
# strach 	 9
#  	 9
# tudo 	 8
# os 	 6
# um 	 6
# ela 	 6
# abraão 	 6
# calisto 	 5
# em 	 5
# uma 	 5
# com 	 5
# mais 	 5
# ele 	 5
# desassombrado 	 5
# se 	 5
# para 	 5
# catedral 	 5
# fita 	 4
# ao 	 4
# como 	 4
# sofia 	 4
# vai 	 4
# eles 	 4
# não 	 4
# tem 	 4
# esse 	 4
# áudio 	 4
# familia 	 3
# as 	 3
# dessa 	 3
# família 	 3
# lugar 	 3
# por 	 3
# na 	 3
# mansão 	 3
# coisas 	 3
# mas 	 3
# depois 	 3
# minha 	 3
# quando 	 3

# %%
import nltk
nltk.download('stopwords')
vazias = nltk.corpus.stopwords.words('portuguese')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
frequente_plenas = [x for x in mf if x[0].lower() not in vazias]
frequente_plenas
# Out:
# [('medo', 10),
#  ('strach', 9),
#  ('', 9),
#  ('tudo', 8),
#  ('abraão', 6),
#  ('calisto', 5)]
